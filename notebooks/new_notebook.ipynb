# %%
print("You are learning about Codespaces in GitHub.")
print("This codespace uses the template for jupyter.")
print("Using GitHub Codespaces with a Jupyter template.")
# Out:
# You are learning about Codespaces in GitHub.
# This codespace uses the template for jupyter.
# Using GitHub Codespaces with a Jupyter template.
